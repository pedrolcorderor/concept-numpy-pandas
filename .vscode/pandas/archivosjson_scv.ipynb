# %%
import pandas as pd

# %%
df_books=pd.read_csv(
    "C:\\numpypandaplatzy\\.vscode\\pandas\\bestsellers-with-categories.csv")
df_books

# %% [markdown]
# la separacion por coma viene por defecto aunque podemos jugar con este,
# tambien podemos asignarle un header en este caso viene por defecto que es la fila 0 , pero podemos especificar cual es o poner como valor NONE y te pondra
# por defecto una numeracion de 1 a n .

# %%
pd.read_csv(
    "C:\\numpypandaplatzy\\.vscode\\pandas\\bestsellers-with-categories.csv",sep=',', header=None)
# Out:
#                                                      0                   1  \
# 0                                                 Name              Author
# 1                        10-Day Green Smoothie Cleanse            JJ Smith
# 2                                    11/22/63: A Novel        Stephen King
# 3              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 546       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 547  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 550  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#                2        3      4     5            6
# ...

# %%
pd.read_csv(
    "C:\\numpypandaplatzy\\.vscode\\pandas\\bestsellers-with-categories.csv", sep=',', header=1)
# Out:
#                          10-Day Green Smoothie Cleanse  \
# 0                                    11/22/63: A Novel
# 1              12 Rules for Life: An Antidote to Chaos
# 2                               1984 (Signet Classics)
# 3    5,000 Awesome Facts (About Everything!) (Natio...
# 4        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 544       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 545  You Are a Badass: How to Stop Doubting Your Gr...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
#
#                      JJ Smith  4.7  17350   8  2016  Non Fiction
# 0                Stephen King  4.6   2052  22  2011      Fiction
# 1          Jordan B. Peterson  4.7  18979  15  2018  Non Fiction
# 2               George Orwell  4.7  21424   6  2017      Fiction
# ...

# %% [markdown]
# cambiar nombres del header aunque, ojo tenemos que identificar la fila , en este caso la de la posicion 0 que es el header ,pero puede ser otro

# %%
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
pd.read_csv(
    "C:\\numpypandaplatzy\\.vscode\\pandas\\bestsellers-with-categories.csv", sep=',', header=0, names=['Namess', 'Authorsss', 'User Ratingsss', 'Reviewssss', 'Pricess', 'Yearss', 'Genress'])
# Out:
#                                                 Namess  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                     Authorsss  User Ratingsss  Reviewssss  Pricess  Yearss  \
# 0                    JJ Smith             4.7       17350        8    2016
# 1                Stephen King             4.6        2052       22    2011
# 2          Jordan B. Peterson             4.7       18979       15    2018
# ...

# %% [markdown]
# ahora con json

# %% [markdown]
# llevamos el archivo json a un data frame

# %%
pd.read_json("C:\\numpypandaplatzy\\.vscode\pandas\\archivojson.json")
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %% [markdown]
# y lo llavamos a una estructura de pandas

# %%
pd.read_json("C:\\numpypandaplatzy\\.vscode\pandas\\archivojson.json",typ='Series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %%
df_books.info
# Out:
# <bound method DataFrame.info of                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 149.4 KB
